# %%
import pandas as pd

# %%
df = pd.read_csv('./glassdoor_comany.csv', encoding='Windows-1252', )
df.head(30)
# Out:
#                       Company Name  Company rating Company reviews  \
# 0                           Amazon             3.8          168.8K
# 1                         Deloitte             4.1           97.2K
# 2                           Target             3.6             75K
# 3                       McDonald's             3.5            117K
# 4                        Accenture             4.0          145.1K
# 5                              IBM             4.0          103.2K
# 6                        Microsoft             4.4           47.8K
# 7        Tata Consultancy Services             3.9          124.2K
# 8   Cognizant Technology Solutions             3.8           84.5K
# 9                        Starbucks             3.7           62.3K
# 10                          Google             4.4           42.9K
# 11                  The Home Depot             3.8           45.2K
# 12                              EY             3.9           69.8K
# ...

# %%
df.shape
# Out:
# (9940, 9)
